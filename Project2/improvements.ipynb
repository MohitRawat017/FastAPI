# %% [markdown]
# - 1. Create a new Folder
# - 2. Field validation for city features
# - 3. Add Routes
# -- a. Home b. Health Check
# - 4. Add model version
# - 5. Seperation of logic ( basically sabko alag karna )
# -- Pydantic model
# -- Ml Logic
# -- FastAPI code etc
# - 6. Try catch behaviors add karna
# - 7. Add the confidence score and better display it with your results
# - 8. Responce Model
