# %% [markdown]
# # FLOW (PROJECT1)
# - Client sends the information to the server side using the \
# POST REQUEST
#
# - Validate - Pydantic Model
#
# - JSON file -> new record will be added

# %% [markdown]
# # FLOW (PROJECT 2)
# - model building  and get the model.pkl
# - api (fastapi)
# - frontend
